# %% [raw]
# ---
# title: "Plots Demo"
# author: "Norah Jones"
# date: "5/22/2021"
# format:
#   html:
#     code-fold: true
#   pdf:
#     geometry:
#         - top=30mm
#         - left=30mm
# jupyter: julia-1.8
# ---

# %%
using Pkg

# %%
using Plots
Plots.gr(fmt = :png)
plot(sin, 
     x->sin(2x), 
     0, 
     2π, 
     leg=false, 
     fill=(0,:lavender))

# %%
Plots._current_plots_version
# Out:
# v"1.27.0"
